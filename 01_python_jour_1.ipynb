# %% [markdown]
# # 🐍 Introduction à Python - Jour 1
#
# Bienvenue dans cette première journée d'initiation à Python.
# Aujourd'hui, nous allons découvrir les bases du langage, sa syntaxe, et quelques constructions fondamentales.

# %% [markdown]
# ___

# %% [markdown]
# ## 🧠 1. Qu’est-ce qu’une variable ?
#
# Une **variable** est un nom qui pointe vers une valeur en mémoire. C’est un outil fondamental pour stocker, manipuler et réutiliser des informations dans un programme.

# %% [markdown]
# ### 🧪 a. Déclaration de variables simples

# %%
x = 42              # entier
name = "Alice"      # chaîne de caractères
pi = 3.14           # flottant
is_active = True    # booléen

# %% [markdown]
# Il existe plusieurs manières d'afficher ces variables

# %%
# Affichage simple
print(x)
print(name)
print(pi)
print(is_active)

print(x, name, pi, is_active)
# Out:
# 42
# Alice
# 3.14
# True
# 42 Alice 3.14 True

# %%
# Affichage à l'aide d'un formatage de chaîne de caractères (str.format())
print("La réponse à tout est : {}".format(x))
print("Bonjour je m'appelle {}".format(name))
print("La valeur du nombre pi est : {}".format(pi))
print("C'est actif ? : {}".format(is_active))

print("Toutes les valeurs : {}, {}, {}, {}".format(x, name, pi, is_active))
# Out:
# La réponse à tout est : 42
# Bonjour je m'appelle Alice
# La valeur du nombre pi est : 3.14
# C'est actif ? : True
# Toutes les valeurs : 42, Alice, 3.14, True

# %%
# Affichage à l'aide d'une interpolation (f-strings literals)
print(f"La réponse à tout est : {x}")
print(f"Bonjour je m'appelle {name}")
print(f"La valeur du nombre pi est : {pi}")
print(f"C'est actif ? : {is_active}")

print(f"Toutes les valeurs : {x}, {name}, {pi}, {is_active}")
# Out:
# La réponse à tout est : 42
# Bonjour je m'appelle Alice
# La valeur du nombre pi est : 3.14
# C'est actif ? : True
# Toutes les valeurs : 42, Alice, 3.14, True

# %% [markdown]
# ### 🔎 b. Le typage dynamique
#
# En Python, on ne précise pas le type : il est **déduit automatiquement**.
#
# Voyons ce qui se passe si on change le type d’une variable :

# %%
print(type(x))
print(type(name))
print(type(pi))
print(type(is_active))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ### 📚 c. Les types de base
#
# | Type        | Exemple        | Description                          |
# |-------------|----------------|--------------------------------------|
# | `int`       | `42`           | Nombre entier                        |
# | `float`     | `3.14`         | Nombre à virgule                     |
# | `str`       | `"Bonjour"`    | Texte                                |
# | `bool`      | `True`         | Booléen                              |

# %% [markdown]
# ### ✅ d. Bonnes pratiques de nommage
#
# - Utiliser des noms **clairs et explicites** (`age`, pas `a`)
# - Éviter les mots-clés réservés (`for`, `class`, `if`, etc.)
# - Utiliser le **snake_case** (convention Python)
# - Ne pas commencer par un chiffre (`2valeurs` ❌)
#
# De manière générale, quand on écrit du code Python, il ne s’agit pas seulement de faire en sorte qu’il fonctionne — il faut aussi qu’il soit **lisible** et **maintenable**.
# Pour cela, Python propose des conventions de style regroupées dans un document officiel : la **PEP 8 (Python Enhancement Proposals)**.
#
# **Lien vers la PEP 8 officielle** :
# [https://peps.python.org/pep-0008/](https://peps.python.org/pep-0008/)

# %% [markdown]
# ### 👨‍💻 e. Exercice : Mon profil python
#
# Créez un script qui affiche vos infos de base.

# %%
# Votre code ici

# %% [markdown]
# ___

# %% [markdown]
# ## ➕ 2. Opérateurs
#
# Les opérateurs permettent de manipuler les variables et les valeurs.

# %%
print(5 + 2)   # addition
print(5 - 2)   # soustraction
print(5 * 2)   # multiplication
print(5 / 2)   # division réelle
print(5 // 2)  # division entière
print(5 % 2)   # modulo
print(5 ** 2)  # puissance

# %% [markdown]
# ___

# %% [markdown]
# ## 🔀 3. Conditions
#
# Les structures conditionnelles permettent d’exécuter du code selon certaines situations.

# %%
age = 20

if age >= 18:
    print("Majeur")
elif age >= 13:
    print("Adolescent")
else:
    print("Enfant")

# %% [markdown]
# ___

# %% [markdown]
# ## 🔁 4. Boucles
#
# Les boucles permettent de répéter une série d’instructions.

# %%
# Boucle for
for i in range(5):
    print("Tour:", i)

# Boucle while
compteur = 0
while compteur < 3:
    print("Compteur:", compteur)
    compteur += 1

# %% [markdown]
# ___

# %% [markdown]
# ## 🛠️ 5. Fonctions natives utiles
#
# Python propose des fonctions intégrées très pratiques.

# %%
nom = input("Quel est ton nom ? ")
print("Bonjour", nom)

texte = "Python"
print(len(texte))       # longueur
print(texte.upper())    # majuscules

# %% [markdown]
# ___

# %% [markdown]
# 👏 Félicitations ! Vous avez vu les bases de Python.
# Demain, on attaque les fonctions, les structures de données et les fichiers !
